# %% [markdown]
# # Data Understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('code/data/final_clean.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6452 entries, 0 to 6451
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 6452 non-null   int64
#  1   release_date       6452 non-null   object
#  2   movie              6452 non-null   object
#  3   production_budget  6452 non-null   int64
#  4   domestic_gross     6452 non-null   int64
#  5   worldwide_gross    6452 non-null   int64
#  6   tconst             6452 non-null   object
#  7   averagerating      6452 non-null   float64
#  8   numvotes           6452 non-null   int64
#  9   primary_title      6452 non-null   object
#  10  original_title     6452 non-null   object
#  11  start_year         6452 non-null   int64
#  12  runtime_minutes    6298 non-null   float64
#  13  genres             6444 non-null   object
#  14  gross_revenue      6452 non-null   int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 756.2+ KB

# %% [markdown]
# # Analysis

# %%
x = df["averagerating"]
y = df["gross_revenue"]
fig, ax = plt.subplots()

def currency(x, pos):
    if x >= 1e6:
        s = '${:1.1f}M'.format(x*1e-6)
    else:
        s = '${:1.0f}K'.format(x*1e-3)
    return s

ax.set_xlabel("Average Rating Score")
ax.set_xlim([0, 10])
ax.set_xticks(np.arange(0, 11, 1))
ax.set_ylabel("Total Gross Revenue")
ax.yaxis.set_major_formatter(currency)
ax.set_title("Correlation Between Rating and Revenue")

plt.scatter(x,y);

plt.savefig("images/review_vs_revenue.png", bbox_inches='tight')

# %%
genre_df = df.groupby("genres")["gross_revenue"].mean()
genre_df = genre_df.astype(int)
genre_df = genre_df.reset_index()

# %%
x = genre_df["genres"]
y = genre_df["gross_revenue"]

fig, ax = plt.subplots()

ax.set_xlabel("Avg Revenue")
ax.xaxis.set_major_formatter(currency)
ax.tick_params(axis='x', labelrotation = 45)
ax.set_ylabel("Genre")
ax.set_title("Average Revenue per Genre")
plt.barh(x, y);

plt.savefig("images/revenue_genre.png", bbox_inches='tight')

# %%
top_genre_df = df.loc[(df['genres'].isin(["Animation", "Adventrue", "Sci-Fi"])) & (df["start_year"] >= 2000)]
top_genre_df = top_genre_df.sort_values(by = ["start_year"])
top_genre_df = top_genre_df.set_index("start_year")

# %%
# Animation_df = Animation_df[["start_year", "gross_revenue"]]
# Animation_df = Animation_df
# Animation_df.rename(columns = {"gross_revenue": "Animation_revenue"}, inplace=True)
